# %% [markdown]
#    #  Data Analysis: Haberman's Cancer Survival Dataset

# %% [markdown]
# ### (1) Dataset Description :

# %% [markdown]
# Sources: (a) Donor: Tjen-Sien Lim (limt@stat.wisc.edu) (b) Date: March 4, 1999 Past Usage:
#
# Haberman, S. J. (1976). Generalized Residuals for Log-Linear Models, Proceedings of the 9th International Biometrics Conference, Boston, pp. 104-122. Landwehr, J. M., Pregibon, D., and Shoemaker, A. C. (1984), Graphical Models for Assessing Logistic Regression Models (with discussion), Journal of the American Statistical Association 79: 61-83. Lo, W.-D. (1993). Logistic Regression Trees, PhD thesis, Department of Statistics, University of Wisconsin, Madison, WI. Relevant Information: The dataset contains cases from a study that was conducted between 1958 and 1970 at the University of Chicago's Billings Hospital on the survival of patients who had undergone surgery for breast cancer.
#
# -  Number of Instances: 306
#
# -  Number of Attributes: 4 (including the class attribute)
#
# -  Attribute Information:
#
#      -  Age of patient at time of operation (numerical)
#
#      -  Patient's year of operation (year - 1900, numerical)
#
#      -  Number of positive axillary nodes detected (numerical)
#
#      -  Survival status (class attribute) 1 = the patient survived 5 years or longer 2 = the patient died within 5 year
#
# -  Missing Attribute Values: None

# %%
# importing libraries :

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# reading dataset 

hbman = pd.read_csv("haberman.csv")
print(hbman.shape)
# Out:
# (305, 4)

# %%
print (hbman.columns)
# Out:
# Index(['30', '64', '1', '1.1'], dtype='object')

# %%
print ("30 => Age of patient at the time of operation")
print ("64 => Patient year of operation in 1900")
print ("1 => Number of positive axillary nodes detected ")
print ("1.1 => Survival status ")
# Out:
# 30 => Age of patient at the time of operation
# 64 => Patient year of operation in 1900
# 1 => Number of positive axillary nodes detected
# 1.1 => Survival status

# %%
survived,not_survived = hbman["1.1"].value_counts()
print ("survived more than 5 years means survived:", survived)
print ("survived less than 5 years means not survived:", not_survived)
# Out:
# survived more than 5 years means survived: 224
# survived less than 5 years means not survived: 81

# %%
hbman
# Out:
#      30  64   1  1.1
# 0    30  62   3    1
# 1    30  65   0    1
# 2    31  59   2    1
# 3    31  65   4    1
# 4    33  58  10    1
# 5    33  60   0    1
# 6    34  59   0    2
# 7    34  66   9    2
# 8    34  58  30    1
# 9    34  60   1    1
# 10   34  61  10    1
# 11   34  67   7    1
# 12   34  60   0    1
# 13   35  64  13    1
# 14   35  63   0    1
# 15   36  60   1    1
# 16   36  69   0    1
# 17   37  60   0    1
# 18   37  63   0    1
# 19   37  58   0    1
# 20   37  59   6    1
# 21   37  60  15    1
# 22   37  63   0    1
# 23   38  69  21    2
# 24   38  59   2    1
# 25   38  60   0    1
# 26   38  60   0    1
# 27   38  62   3    1
# 28   38  64   1    1
# 29   38  66   0    1
# ..   ..  ..  ..  ...
# 275  67  66   0    1
# 276  67  61   0    1
# 277  67  65   0    1
# 278  68  67   0    1
# 279  68  68   0    1
# 280  69  67   8    2
# 281  69  60   0    1
# 282  69  65   0    1
# 283  69  66   0    1
# 284  70  58   0    2
# 285  70  58   4    2
# ...

# %% [markdown]
# ## (2) 2D- Scatter Plot

# %%
# 2D scatter plot with age of patitent on x axis and number of positive axillary node on y axis

hbman.plot(kind='scatter', x='30', y='1', label='2D-Scatter plot');
plt.legend()
plt.xlabel("Patient's age at time of operation")
plt.ylabel("Number of Axillary nodes detected")
plt.show()

# %%
# 2D scatter plot between 
hbman.plot(kind='scatter', x='30', y='64', label='2D-Scatter plot');
plt.legend()
plt.xlabel("Patient's age at time of operation")
plt.ylabel("Patient year of operation in 1900")
plt.show()

# %%
hbman.plot(kind='scatter', x='64', y='1', label='2D-Scatter plot');
plt.legend()
plt.xlabel("patient's year of operation in 1900")
plt.ylabel("Number of positive Axillary nodes Detected")
plt.show()

# %% [markdown]
# ## FacetGrid

# %%
sns.set_style("darkgrid")
sns.FacetGrid(hbman,hue="1.1",size=5).map(plt.scatter,"30","1").add_legend()
plt.xlabel("patient's age at time of operation")
plt.ylabel("Number of positive axillary nodes detected")
plt.show()

# %% [markdown]
# # pair plot

# %%
plt.close();
sns.set_style("darkgrid");
sns.pairplot(hbman,hue="1.1" ,vars=['30','64','1'],size=4);
plt.show()

# %% [markdown]
# # histogram, CDF, PDF

# %%
survived_more_5=hbman.loc[hbman["1.1"] == 1]
survived_less_5=hbman.loc[hbman["1.1"] == 2]
plt.plot(survived_more_5["1"],np.zeros_like(survived_more_5["1"]),'o',label="survived More than five")
plt.plot(survived_less_5["1"],np.zeros_like(survived_less_5["1"]),'o',label="survived less than five")
plt.xlabel("Number of auxilary nodes detected")
plt.legend()
plt.show()

# %%
sns.FacetGrid(hbman,hue="1.1",size=5).map(sns.distplot,"1").add_legend();
plt.xlabel("Number of auxilary nodes detected")
plt.show()
# Out:
# C:\Users\himan\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\himan\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.FacetGrid(hbman,hue="1.1",size=5).map(sns.distplot,"30").add_legend();
plt.xlabel("Age of patients at which operation is done")
plt.show()
print(max(hbman["30"]))
# Out:
# C:\Users\himan\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\himan\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# 83

# %%
sns.FacetGrid(hbman,hue="1.1",size=5).map(sns.distplot,"64").add_legend();
plt.xlabel("year in which Cancer operation is done")
plt.show()
# Out:
# C:\Users\himan\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\himan\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ## PDF and CDF of each parameter

# %%
counts,values = np.histogram(survived_more_5['30'],bins=5,density=True)
pdf = counts/(sum(counts))
cdf = np.cumsum(pdf)
plt.plot(values[1:],pdf,label="pdf(survival cases according to age)")
plt.plot(values[1:],cdf,label="cdf(survival cases according to age)")
plt.xlabel("patient's age at time of operation")
plt.legend()
plt.show()

# %%
counts,values= np.histogram(survived_less_5["30"],density=True,bins=5)
pdf = counts/(sum(counts))
cdf = np.cumsum(pdf)
plt.plot(values[1:],pdf,label="pdf(non-survival cases according to age)")
plt.plot(values[1:],cdf,label="cdf(non-survival cases according to age)")
plt.xlabel("patient's age at time of operation")
plt.legend()
plt.show()

# %%
counts,values = np.histogram(survived_more_5['1'],density=True,bins=5)
pdf = counts/(sum(counts))
cdf = np.cumsum(pdf)
plt.plot(values[1:],pdf,label="pdf(lived more than 5 years)")
plt.plot(values[1:],cdf,label="cdf(lived more than five years)")
plt.legend()
plt.xlabel("Number of auxilary nodes detected")
plt.show()

# %%
counts,values = np.histogram(survived_less_5['1'],density=True,bins=5)
pdf = counts/(sum(counts))
cdf = np.cumsum(pdf)
plt.plot(values[1:],pdf,label="pdf(not lived more than 5 years)")
plt.plot(values[1:],cdf,label="cdf(not lived more than five years)")
plt.legend()
plt.xlabel("Number of auxilary nodes detected")
plt.show()

# %%
print("average age of survived patient's",np.mean(survived_more_5["30"]))
print("    ")
print("average detected auxilary nodes in survived patient's",np.mean(survived_more_5["1"]))
print("    ")
print("average age of unsurvived patient's",np.mean(survived_less_5["30"]))
print("    ")
print("average detected auxilary nodes of unsurvived patient's",np.mean(survived_less_5["1"]))
print("    ")
print("spread age of survived patient's",np.std(survived_more_5["30"]))
print("    ")
print("spread detected auxilary nodes in survived patient's",np.std(survived_more_5["1"]))
print("    ")
print("spread age of unsurvived patient's",np.std(survived_less_5["30"]))
print("    ")
print("spread detected auxilary nodes of unsurvided patient's",np.std(survived_less_5["1"]))
# Out:
# average age of survived patient's 52.11607142857143
#
# average detected auxilary nodes in survived patient's 2.799107142857143
#
# average age of unsurvived patient's 53.67901234567901
#
# average detected auxilary nodes of unsurvived patient's 7.45679012345679
#
# spread age of survived patient's 10.913004640364269
#
# spread detected auxilary nodes in survived patient's 5.869092706952767
#
# spread age of unsurvived patient's 10.10418219303131
#
# spread detected auxilary nodes of unsurvided patient's 9.128776076761632

# %% [markdown]
# # Median,Percentiles,Quantiles,IQR,Mad

# %% [markdown]
# ### Median

# %%
print("average age of survived patient's",np.median(survived_more_5["30"]))
print("average dected auxilary nodes in survived patient's",np.median(survived_more_5["1"]))
print("average age of unsurvived patient's",np.median(survived_less_5["30"]))
print("average dectected auxilary nodes survived patient's",np.median(survived_less_5["1"]))
# Out:
# average age of survived patient's 52.0
# average dected auxilary nodes in survived patient's 0.0
# average age of unsurvived patient's 53.0
# average dectected auxilary nodes survived patient's 4.0

# %% [markdown]
# ### Quatile

# %%
print("Quantiles with respect to auxilary nodes of survived patients",np.percentile(survived_more_5["1"],np.arange(0,100,25)))
print("Quantiles with respect to auxilary nodes of unsurvived patients",np.percentile(survived_less_5["1"],np.arange(0,100,25)))
# Out:
# Quantiles with respect to auxilary nodes of survived patients [0. 0. 0. 3.]
# Quantiles with respect to auxilary nodes of unsurvived patients [ 0.  1.  4. 11.]

# %% [markdown]
# ### 90th Percentile

# %%
print("90th percentile of auxilary nodes of survived patients",np.percentile(survived_more_5["1"],90))
print("90th percentile of auxilary nodes of unsurvived patients",np.percentile(survived_less_5["1"],90))
# Out:
# 90th percentile of auxilary nodes of survived patients 8.0
# 90th percentile of auxilary nodes of unsurvived patients 20.0

# %% [markdown]
# ### Box plots and Whiskers

# %%
sns.boxplot(x="1.1",y="1",data=hbman)
plt.xlabel("1-survived patient's and 2-unsurvived patient's")
plt.ylabel("number of auxilary nodes detected")
plt.show()

# %% [markdown]
# ### Violin Plots

# %%
sns.violinplot(x="1.1",y="1",data=hbman,size=9)
plt.xlabel("1-survived patient's and 2-unsurvived patient's")
plt.ylabel("number of auxilary nodes detected")
plt.show()

# %% [markdown]
# ### Joint-point

# %%
sns.jointplot(x="30",y="1",data=hbman,kind="kde",space=0.6)
#plt.title("Joint plot of survived patients with detected nodes")
plt.xlabel("patient's age")
plt.ylabel("auxilary nodes detected")
plt.show()
